# %% [markdown]
# **해군사 AI 과정**
#
# Day 2:
#
# User:
#
# 실습 #1: Python 처음 사용하기

# %% [markdown]
# # **실습 #1-1: 파이썬 리스트 만들어보기**

# %% [markdown]
# **제 55회 백상예술대상 영화부문 후보**
# ![백상 예술대상.jpg](data:image/jpeg;base64,...)

# %%
작품상 = ['공작', '미쓰백', '버닝', '사바하', '암수살인']
감독상 = ['강형철', '윤종빈', '이창동', '이해영', '장재현']
신인_감독상 = ['김의석', '신동석', '이석근', '이종언', '이지원']
남자_최우수연기상 = ['류승룡', '유아인', '이성민', '정우성', '주지훈']
여자_최우수연기상 = ['고아성', '김향기', '김혜수', '김희애', '한지민']

# (TODO) 위 리스트들을 하나씩 차례대로 출력

# %%
# (TODO) 작품상 평가

# %% [markdown]
# # **실습 #1-2: 파이썬 리스트 인덱싱(indexing) 하기(리스트 내 데이터 지칭하기)**

# %%
# (TODO) 작품상 리스트의 4 번째 값 평가

# %%
# (TODO) 작품상 리스트의 마지막 값 평가

# %%
"""
이제 변수명을 영어로 사용합시다.
감독의 정보를 리스트에 넣읍시다. (https://ko.wikipedia.org/wiki/%EC%98%81%ED%99%94_%EA%B0%90%EB%8F%85_%EB%AA%A9%EB%A1%9D)
- 강우석, 류승완, 봉준호, 임권택, 장진
- 형식: [성, [최종학교, 데뷔해, 태어난해, 국적], 마지막 작품 년도]
  - wiki에 정보가 없으면 None
"""
kang = ['kang', ['SKKU',1988, 1960, "Korea"], 2016]
ryu = ['ryu', [None, 1996, 1973, "Korea"], 2017]
bong = ['bong', ['Yonsei', 1993, 1969, "Korea"], 2019]
lim = ['lim', ['Gwangju', 1953, 1936, "Korea"], 2004]
jang = ['jang', ['Seoul_art', 1995, 1971, "Korea"], 2020]

# (TODO) 위 5 개의 리스트를 차례대로 출력

# %%
# (TODO) ['SKKU',1988, 1960, "Korea"] 을 평가하기 위한 인덱싱 // 변수 kang로부터

# %%
# (TODO) 1988 을 평가하기 위한 인덱싱: 다중 인덱싱 // 변수 kang로부터

# %%
# 데뷔해와 태어난 해를 리스트 화 하여 element로 추가 // 좀 더 복잡한 리스트 형태
kang = ['kang', ['SKKU',[1988, 1960], "Korea"], 2016]
ryu = ['ryu', [None, [1996, 1973], "Korea"], 2017]
bong = ['bong', ['Yonsei', [1993, 1969], "Korea"], 2019]
lim = ['lim', ['Gwangju', [1953, 1936], "Korea"], 2004]
jang = ['jang', ['Seoul_art', [1995, 1971], "Korea"], 2020]
print(kang)
print(ryu)
print(bong)
print(lim)
print(jang)
# Out:
# ['kang', ['SKKU', [1988, 1960], 'Korea'], 2016]
# ['ryu', [None, [1996, 1973], 'Korea'], 2017]
# ['bong', ['Yonsei', [1993, 1969], 'Korea'], 2019]
# ['lim', ['Gwangju', [1953, 1936], 'Korea'], 2004]
# ['jang', ['Seoul_art', [1995, 1971], 'Korea'], 2020]

# %%
# (TODO) bong[1][1] 평가하여 갑 확인

# %%
# (TODO) 1993 을 평가하기 위한 인덱싱: 다중 인덱싱 // 변수 bong로부터

# %% [markdown]
# # **실습 #1-3: 파이썬 리스트 슬라이싱(slicing) 하기(리스트 내 데이터 일부 구간 가져오기)**

# %%
# slicing 실습 1

# %%
# slicing 실습 2

# %%
# slicing 실습 3

# %% [markdown]
# ---

# %%
data = [1,5,3,7,1,2,5,6,8]
data

# %%
# (TODO) slicing을 사용하여 처음부터 4개의 데이터 뽑아내기

# %%
# (TODO) slicing을 사용하여 index 2부터 index 6까지의 데이터 뽑아내기

# %%
# kang[1][1:3]의 값을 평가해보기

# %% [markdown]
# # **실습 #1-4: 파이썬 리스트 값 수정하기**

# %%
lim

# %%
ryu

# %%
# (TODO) lim의 마지막 작품 년도를 2021로 변경

# %%
# (TODO) ryu의 마지막 작품 년도도 2021로 변경

# %% [markdown]
# # **실습 #1-5: 파이썬 리스트 값 지우기**

# %%
kang

# %%
# kang 리스트에서 최종학교 정보 삭제하기 (del 사용)

# %% [markdown]
# # **실습 #1-6: 행렬 형태의 리스트**

# %%
kang = ['kang', ['SKKU',[1988, 1960], "Korea"], 2016]
ryu = ['ryu', [None, [1996, 1973], "Korea"], 2017]
bong = ['bong', ['Yonsei', [1993, 1969], "Korea"], 2019]
lim = ['lim', ['Gwangju', [1953, 1936], "Korea"], 2004]
jang = ['jang', ['Seoul_art', [1995, 1971], "Korea"], 2020]

# %%
# (TODO) director 리스트의 각 요소가 위의 kang부터 jang까지 리스트가 되도록 만들기

# %%
# (TODO) director의 첫 번째 요소 평가

# %%
# (TODO) director의 두 번째 요소 평가

# %% [markdown]
# # **실습 #1-7: 반복문(for) 사용하기 - director 데이터에 Korea 부분만 삭제하고 싶은데 일일이 del 함수로 삭제하는 것 말고 다른 방법이 없을까?**

# %%
# (TODO) range()를 이용하여 0부터 4까지의 리스트 생성

# %%
# (TODO) range()를 이용하여 [1, 2] 리스트 생성

# %%
# (TODO) range()를 이용하여 [0, 2, 4, 6, 8] 리스트 생성

# %%
# (TODO) range()를 이용하여 [10, 8, 6, 4, 2] 리스트 생성

# %%
for i in range(1, 10):   # for문을 사용하여, 1부터 (10-1)까지 출력
  print(i)

# %%
# (TODO) for문, range()를 사용하여 1부터 9까지의 합을 구하는 프로그램 작성
# Out:
# 45

# %%
director

# %%
# (TODO) for문을 이용하여 director 안에 있는 "Korea"를 모두 삭제

# %% [markdown]
# # **실습 #1-8: 서로 다른 리스트 끼리 붙이기: + 연산, append 함수, extend 함수**

# %%
a = [1, 2, 3]
b = [4, 5]

# %%
# (TODO) c = a + b 평가해보기

# %%
# (TODO) a.extend(b) 평가해보기

# %%
# (TODO) a.append(b) 평가해보기

# %% [markdown]
# > 감독 리스트로 진행해보기

# %%
# 기존 감독들 데이터에 내부 리스트 형식 제거 (일차 리스트로)
kang = ['kang', 'SKKU', 1988, 1960, "Korea", 2016]
ryu = ['ryu', None, 1996, 1973, "Korea", 2017]
bong = ['bong', 'Yonsei', 1993, 1969, "Korea", 2019]
lim = ['lim', 'Gwangju', 1953, 1936, "Korea", 2004]
jang = ['jang', 'Seoul_art', 1995, 1971, "Korea", 2020]
director = [kang, ryu, bong, lim, jang]
director

# %%
kim = ['kim', 'MIT', 2000, 1981, "USA", 2020]
kim

# %% [markdown]
# > 다음과 같이 데이터가 되기를 원함
#
# **[ ['kang', 'SKKU', 1988, 1960, 'Korea', 2016],\
#   ['ryu', None, 1996, 1973, 'Korea', 2017],\
#   ['bong', 'Yonsei', 1993, 1969, 'Korea', 2019],\
#   ['lim', 'Gwangju', 1953, 1936, 'Korea', 2004],\
#   ['jang', 'Seoul_art', 1995, 1971, 'Korea', 2020],\
#   ['kim', 'MIT', 2000, 1981, 'USA', 2020]]**

# %%
# 안됨1 - 실행해 보세요
director0 = director + kim
director0

# %%
# 안됨2 - 실행해 보세요
director0 = director.copy() # director의 내용을 변경시키지 않기 위해 copy()로 넘겨줌
director0.extend(kim)
director0

# %%
# (TODO) 해결법 1 (append 사용)
director0 = director.copy()

# %%
# (TODO) 해결법 2 (extend 사용)
director0 = director.copy()

# %% [markdown]
# # **실습 #1-9: 리스트 내 원하는 위치에 데이터 넣기**

# %%
kang = ['kang', 'SKKU', 1988, 1960, "Korea", 2016]
ryu = ['ryu', None, 1996, 1973, "Korea", 2017]
bong = ['bong', 'Yonsei', 1993, 1969, "Korea", 2019]
lim = ['lim', 'Gwangju', 1953, 1936, "Korea", 2004]
jang = ['jang', 'Seoul_art', 1995, 1971, "Korea", 2020]
director = [kang, ryu, bong, lim, jang]
director

# %%
kim = ['kim', 'MIT', 2000, 1981, "USA", 2020]
kim

# %%
# (TODO) director 리스트의 2 번째에 kim 정보를 넣기! (이전 해결법 형태처럼, 행 데이터로 넣기!)
